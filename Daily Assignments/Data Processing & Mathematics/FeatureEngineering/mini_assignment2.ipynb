# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data = {"Department": ["HR", "IT", "Finance", "IT"]}
df = pd.DataFrame(data)
df
# Out:
#   Department
# 0         HR
# 1         IT
# 2    Finance
# 3         IT

# %%
le = LabelEncoder()
df["Encoded"] = le.fit_transform(df["Department"])
df
# Out:
#   Department  Encoded
# 0         HR        1
# 1         IT        2
# 2    Finance        0
# 3         IT        2

# %%
pd.get_dummies(df["Department"])
# Out:
#    Finance     HR     IT
# 0    False   True  False
# 1    False  False   True
# 2     True  False  False
# 3    False  False   True

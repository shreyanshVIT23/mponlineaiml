# %%
import seaborn as sns
import pandas as pd

# %%
data = {"Age": [20, 25, 30, 35, 40], "Salary": [25000, 30000, 40000, 50000, 65000]}
df = pd.DataFrame(data)
df.head(3)
# Out:
#    Age  Salary
# 0   20   25000
# 1   25   30000
# 2   30   40000

# %%
df["Salary"].mean()
# Out:
# np.float64(42000.0)

# %%
df["Age"].max()
# Out:
# np.int64(40)

# %%
sns.histplot(df["Salary"])
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.boxplot(x=df["Salary"])
# Out:
# <Axes: xlabel='Salary'>

# %%
df.corr()
# Out:
#              Age    Salary
# Age     1.000000  0.985329
# Salary  0.985329  1.000000
